# %% [markdown]
# ## **Mushroom Edibility Classification**
# SHAHIN SAIFI
#
#
# CSAI 2
#
# 2nd Year

# %%
import pandas as pd

df=pd.read_csv("/content/Mushroon_Data.csv", sep=';')
df.head()
# Out:
#   class  cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0     p         15.26         x           g         o                    f
# 1     p         16.60         x           g         o                    f
# 2     p         14.07         x           g         o                    f
# 3     p         14.17         f           h         e                    f
# 4     p         14.64         x           h         o                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  ...  stem-root  \
# 0               e          NaN          w        16.95  ...          s
# 1               e          NaN          w        17.99  ...          s
# 2               e          NaN          w        17.80  ...          s
# 3               e          NaN          w        15.77  ...          s
# 4               e          NaN          w        16.53  ...          s
#
#   stem-surface stem-color veil-type veil-color has-ring ring-type  \
# ...

# %%
df.shape
# Out:
# (61069, 21)

# %%
df.describe()
# Out:
#        cap-diameter   stem-height    stem-width
# count  61069.000000  61069.000000  61069.000000
# mean       6.733854      6.581538     12.149410
# std        5.264845      3.370017     10.035955
# min        0.380000      0.000000      0.000000
# 25%        3.480000      4.640000      5.210000
# 50%        5.860000      5.950000     10.190000
# 75%        8.540000      7.740000     16.570000
# max       62.340000     33.920000    103.910000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61069 entries, 0 to 61068
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   class                 61069 non-null  object
#  1   cap-diameter          61069 non-null  float64
#  2   cap-shape             61069 non-null  object
#  3   cap-surface           46949 non-null  object
#  4   cap-color             61069 non-null  object
#  5   does-bruise-or-bleed  61069 non-null  object
#  6   gill-attachment       51185 non-null  object
#  7   gill-spacing          36006 non-null  object
#  8   gill-color            61069 non-null  object
#  9   stem-height           61069 non-null  float64
#  10  stem-width            61069 non-null  float64
#  11  stem-root             9531 non-null   object
#  12  stem-surface          22945 non-null  object
#  13  stem-color            61069 non-null  object
#  14  veil-type             3177 non-null   object
# ...

# %%
d1.isnull().sum()
# Out:
# class                       0
# cap-diameter                0
# cap-shape                   0
# cap-surface             14120
# cap-color                   0
# does-bruise-or-bleed        0
# gill-attachment          9884
# gill-spacing            25063
# gill-color                  0
# stem-height                 0
# stem-width                  0
# stem-root               51538
# stem-surface            38124
# stem-color                  0
# veil-type               57892
# veil-color              53656
# has-ring                    0
# ring-type                2471
# spore-print-color       54715
# habitat                     0
# season                      0
# dtype: int64

# %%
df['class'].value_counts()
# Out:
# 1    33888
# 0    27181
# Name: class, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(data=d1,x='class',palette='autumn')

# %%
d1.corr()
# Out:
#               cap-diameter  stem-height  stem-width
# cap-diameter       1.00000     0.422560    0.695330
# stem-height        0.42256     1.000000    0.436117
# stem-width         0.69533     0.436117    1.000000

# %%
sns.heatmap(d1.corr(),cmap='YlGnBu')
plt.show()

# %%
sns.heatmap(d1.corr())

# %%
plt.figure(figsize = (5,5))
g = sns.catplot(x="cap-shape", hue="cap-color", col="class",
                data=df, kind="count",
                height=5, aspect=.7);

# %% [markdown]
# *  White Coloured and Bell Shaped Mushrooms are highly recommended for eating
# *   Red Coloured Knobbed Shaped Mushrooms are poisonous

# %%
sns.pairplot(d1, hue='class', size=2.5);
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.violinplot(data=d1[['cap-diameter', 'stem-height', 'stem-width']])

# %%
from sklearn.preprocessing import LabelEncoder
mappings = list()

encoder = LabelEncoder()

for column in range(len(d1.columns)):
    d1[d1.columns[column]] = encoder.fit_transform(d1[d1.columns[column]])
    mappings_dict = {index: label for index, label in enumerate(encoder.classes_)}
    mappings.append(mappings_dict)

# %%
mappings
# Out:
# [{0: 'e', 1: 'p'},
#  {0: 0.38,
#   1: 0.44,
#   2: 0.47,
#   3: 0.48,
#   4: 0.49,
#   5: 0.5,
#   6: 0.51,
#   7: 0.52,
#   8: 0.53,
#   9: 0.54,
#   10: 0.55,
#   11: 0.56,
#   12: 0.57,
#   13: 0.58,
#   14: 0.59,
#   15: 0.6,
#   16: 0.61,
#   17: 0.62,
#   18: 0.63,
#   19: 0.64,
#   20: 0.65,
#   21: 0.66,
#   22: 0.67,
#   23: 0.68,
#   24: 0.69,
#   25: 0.7,
#   26: 0.71,
#   27: 0.72,
#   28: 0.73,
#   29: 0.74,
#   30: 0.75,
#   31: 0.76,
#   32: 0.77,
#   33: 0.78,
#   34: 0.79,
#   35: 0.8,
#   36: 0.81,
#   37: 0.82,
#   38: 0.83,
#   39: 0.84,
#   40: 0.85,
#   41: 0.86,
#   42: 0.87,
#   43: 0.88,
#   44: 0.89,
#   45: 0.9,
#   46: 0.91,
#   47: 0.92,
#   48: 0.93,
#   49: 0.94,
#   50: 0.95,
#   51: 0.96,
#   52: 0.97,
#   53: 0.98,
#   54: 0.99,
#   55: 1.0,
#   56: 1.01,
#   57: 1.02,
#   58: 1.03,
#   59: 1.04,
#   60: 1.05,
#   61: 1.06,
#   62: 1.07,
#   63: 1.08,
#   64: 1.09,
#   65: 1.1,
#   66: 1.11,
#   67: 1.12,
#   68: 1.13,
#   69: 1.14,
#   70: 1.15,
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df = df.apply(LabelEncoder().fit_transform)   
df.head()
# Out:
#    class  cap-diameter  cap-shape  cap-surface  cap-color  \
# 0      1          1481          6            2          6
# 1      1          1614          6            2          6
# 2      1          1362          6            2          6
# 3      1          1372          2            3          1
# 4      1          1419          6            3          6
#
#    does-bruise-or-bleed  gill-attachment  gill-spacing  gill-color  \
# 0                     0                2             3          10
# 1                     0                2             3          10
# 2                     0                2             3          10
# 3                     0                2             3          10
# 4                     0                2             3          10
#
#    stem-height  ...  stem-root  stem-surface  stem-color  veil-type  \
# 0         1577  ...          4             7          11          0
# 1         1681  ...          4             7          11          0
# ...

# %%
from sklearn.model_selection import train_test_split
y = d1['class']
x = d1.drop('class', axis=1)
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.05, random_state = 0)
print(f'Data Split done.')
# Out:
# Data Split done.

# %%
# # Pre-processing: Normalization / Scaling
# from sklearn.preprocessing import StandardScaler
# sc=StandardScaler() # Machine Instance
# train_scaled=pd.DataFrame(sc.fit_transform(X_train)) # Scaling the train set
# test_scaled=pd.DataFrame(sc.transform(X_test)) # Scaling the test set

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
train = pd.DataFrame(scaler.fit_transform(X_train))
test =pd.DataFrame(scaler.fit_transform(X_test))

# %% [markdown]
# **Decision tree model**

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix, classification_report

model=DecisionTreeClassifier()
model.fit(train,y_train)

# %%
predictions_train=model.predict(train) # Predicting for train set
accuracy_of_train=accuracy_score(y_train,predictions_train) # Calculating accuracy

predictions_test=model.predict(test) # Predicting on test set
accuracy_of_test=accuracy_score(y_test,predictions_test)

# %%
print(classification_report(y_test,predictions_test ))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1311
#            1       1.00      1.00      1.00      1743
#
#     accuracy                           1.00      3054
#    macro avg       1.00      1.00      1.00      3054
# weighted avg       1.00      1.00      1.00      3054

# %% [markdown]
# **Random forest model**

# %%
from sklearn.ensemble import RandomForestClassifier
model_2=RandomForestClassifier() # Machine Instance
model_2.fit(train,y_train)# Training the model

# Predictions made
predict_train=model_2.predict(train)
predict_test=model_2.predict(test)

# accuracy calculation
accuracy_train=accuracy_score(predict_train,y_train)
accuracy_test=accuracy_score(predict_test,y_test)

# %%
print(classification_report(y_test,predict_test ))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1311
#            1       1.00      1.00      1.00      1743
#
#     accuracy                           1.00      3054
#    macro avg       1.00      1.00      1.00      3054
# weighted avg       1.00      1.00      1.00      3054

# %%
cf_matrix_3 = confusion_matrix(y_test,predict_test)
categories  = ['Poisonous','Edible']
group_names = ['True Neg','False Pos', 'False Neg','True Pos']
sns.heatmap(cf_matrix_3,xticklabels = categories, yticklabels = categories,cmap='autumn')
